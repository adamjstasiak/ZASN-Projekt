# %%
# !pip install transformers torch datasets accelerate bitsandbytes sentencepiece vllm
# The model is an Unsloth model. If trust_remote_code=True relies on the Unsloth library
# for custom model code, you MUST install Unsloth.
# !pip install "unsloth[colab-newest]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/fxmeng/TransMLA.git
# Out:
# Cloning into 'TransMLA'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 151 (delta 79), reused 101 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 178.05 KiB | 959.00 KiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
output_save_path = "/content/TransMLA/transmla_output_deepseek" # Example local path
# output_save_path = "/content/drive/MyDrive/TransMLA_outputs_DeepSeek" # Example Google Drive path

import os
os.makedirs(output_save_path, exist_ok=True)

# !python TransMLA/main.py \
    --model-path "unsloth/DeepSeek-R1-Distill-Qwen-1.5B" \
    --dtype "bf16" \
    --device "cuda" \
    --cal-dataset "wikitext2" \
    --cal-nsamples 128 \
    --cal-max-seqlen 2048 \
    --seed 42 \
    --save-path f"{output_save_path}" \
    \
    --ppl-eval-batch-size 1 \
    --cal-batch-size 1 \
    --dim2head 4 \
    --q-lora-rank 512 \
    --kv-lora-rank 256 \
    --v-mqa-dim 64 \
    --rope-head 1 \
    --qk-mqa-dim 64
# Out:
# config.json: 100% 679/679 [00:00<00:00, 4.02MB/s]
# 2025-05-06 11:44:05.357626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746531845.572632    2067 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746531845.629067    2067 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 11:44:06.079726: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !git clone https://github.com/bet0x/transmla-converter.git
# Out:
# Cloning into 'transmla-converter'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 21 (delta 8), reused 13 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 18.62 KiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !pip install flash-attn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 64.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flash-attn: filename=flash_attn-2.7.4.post1-cp311-cp311-linux_x86_64.whl size=187831595 sha256=58853b28a5a926cae14402bfd8d4d93a45ebf8f9e79533f37ab09d0d77a99c05
#   Stored in directory: /root/.cache/pip/wheels/3d/88/d8/284b89f56af7d5bf366b10d6b8e251ac8a7c7bf3f04203fb4f
# Successfully built flash-attn
# ...

# %%
# !python transmla-converter/transmla_converter.py --model "unsloth/DeepSeek-R1-Distill-Qwen-1.5B"  --output "deepseek-r1-qwen-1.5b-mla"
# Out:
# 2025-05-06 12:49:24.948187: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746535764.968058   18795 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746535764.974331   18795 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 12:49:24.995477: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !tar -zcvf deepseek-r1-qwen-1.5b-mla.tar.gz deepseek-r1-qwen-1.5b-mla/
# Out:
# deepseek-r1-qwen-1.5b-mla/
# deepseek-r1-qwen-1.5b-mla/special_tokens_map.json
# deepseek-r1-qwen-1.5b-mla/tokenizer.json
# deepseek-r1-qwen-1.5b-mla/config.json
# deepseek-r1-qwen-1.5b-mla/model.safetensors
# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls deepseek-r1-qwen-1.5b-mla/
# Out:
# config.json		model.safetensors	 tokenizer_config.json
# generation_config.json	special_tokens_map.json  tokenizer.json

# %%
# !cp /content/deepsseek-r1-qwen-1.5b-mla/model.safetensors /content/drive/MyDrive/
# Out:
# cp: cannot stat '/content/deepsseek-r1-qwen-1.5b-mla/model.safetensors': No such file or directory
